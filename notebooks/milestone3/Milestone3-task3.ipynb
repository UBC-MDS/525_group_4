# %% [markdown]
# # Task 3

# %% [markdown]
# This notebook is part of Milestone 3, Question 3. You can work on this notebook on your laptop to develop your machine learning model using all the learnings from the previous courses. At the end of this notebook, when you are ready to train the model, you will need to obtain the hyperparameters from the hyperparameter tuning job that you will run in Milestone 3 Question 4 (i.e., the notebook named `Milestone3-Task4.ipynb`).
#
# PS: To speed up the process, you can test the model without the hyperparameters first. Once other team members obtain the hyperparameters, you can retrain the model using those hyperparameters and test it again.

# %%
# I asked them to use their laptop so they already got all these packages from previous courses.
# %pip install joblib scikit-learn matplotlib s3fs

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import os
from joblib import dump, load
import altair as alt
import altair_ally as aly
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 16, 'axes.labelweight': 'bold', 'figure.figsize': (8,6)})
## add any other additional packages that you need. You are free to use any packages for vizualization.
# Save a vega-lite spec and a PNG blob for each plot in the notebook
alt.renderers.enable('mimetype')
# Handle large data sets without embedding them in the notebook
alt.data_transformers.enable('data_server')
# Out:
# DataTransformerRegistry.enable('data_server')

# %% [markdown]
# ## Part 1:

# %% [markdown]
# Recall as a final goal of this project. We want to build and deploy ensemble machine learning models in the cloud, where features are outputs of different climate models and the target is the actual rainfall observation. In this milestone, you'll actually build these ensemble machine learning models in the cloud.
#
# **Your tasks:**
#
# 1. Read the data CSV from your s3 bucket.
# 2. Drop rows with nans.
# 3. Split the data into train (80%) and test (20%) portions with `random_state=123`.
# 4. Carry out EDA of your choice on the train split.
# 5. Train ensemble machine learning model using `RandomForestRegressor` and evaluate with metric of your choice (e.g., `RMSE`) by considering `Observed` as the target column.
# 6. Discuss your results. Are you getting better results with ensemble models compared to the individual climate models?
#
# > Recall that individual columns in the data are predictions of different climate models.

# %%
## Remember by default it looks for credentials in home directory. 
## Make sure your updated credentials are in home directory
## or pass credentials explicitly and pass as storage_options=aws_credentials (not a good idea)
# aws_credentials = {"key": "","secret": "","token":""}
# replace with s3 path to your data

### Step 1: Read the data
os.environ["AWS_SHARED_CREDENTIALS_FILE"] = "~/.aws/credentials"
df = pd.read_csv("s3://mds-s3-4-mrnabiz/output/ml_data_SYD.csv", index_col=0, parse_dates=True)

# %%
### Step 2: Drop NAs
df = df.dropna()

# %%
## Step 3: Train Test Split
train_df, test_df = train_test_split(df, 
                                     test_size=0.2, 
                                     random_state=123)

X_train, y_train = train_df.drop(columns=["Observed"]), train_df["Observed"]
X_test, y_test = test_df.drop(columns=["Observed"]), test_df["Observed"]

# %%
## Step 4: EDA
X_train.head()
# Out:
#             ACCESS-CM2  ACCESS-ESM1-5  AWI-ESM-1-1-LR  BCC-CSM2-MR  \
# time
# 1953-10-26   17.906051       0.837579    9.753198e-14     0.018863
# 1921-10-22    0.515505       1.911354    1.135404e+00     0.000002
# 1925-01-22    0.161412       2.666091    7.012887e-02     2.040689
# 1902-11-21    3.651607       3.117433    1.142701e-13     0.000016
# 1925-02-17    0.635625      39.042773    1.084678e+00    31.690315
#
#                 BCC-ESM1  CMCC-CM2-HR4  CMCC-CM2-SR5  CMCC-ESM2   CanESM5  \
# time
# 1953-10-26  2.878923e-01      0.007043      0.122719  10.855838  0.022752
# 1921-10-22  4.091981e-01      0.009669      0.074208   1.239226  3.566098
# 1925-01-22  1.338349e+01      0.073243      0.000255   1.349633  0.075959
# 1902-11-21  4.658142e-09      3.913076      9.442968   0.720382  5.314680
# 1925-02-17  6.208601e-09      0.416932      0.733783   0.004239  0.439862
#
#             EC-Earth3-Veg-LR  ...     MIROC6  MPI-ESM-1-2-HAM  MPI-ESM1-2-HR  \
# time                          ...
# 1953-10-26          0.472927  ...   0.456327     6.688447e+00       2.860546
# 1921-10-22          0.667190  ...  10.748933     2.368273e-01       0.652848
# 1925-01-22          0.059223  ...   0.001945     1.082573e-01       2.977031
# 1902-11-21          0.122738  ...   2.310382     1.635075e-01       0.021314
# 1925-02-17          0.404930  ...   0.011038     4.388535e-13       0.025447
#
#             MPI-ESM1-2-LR    MRI-ESM2-0         NESM3    NorESM2-LM  \
# time
# 1953-10-26   9.779330e-14  2.980863e-01  1.659176e-13  3.841924e+00
# 1921-10-22   1.132699e-13  7.653117e-08  4.560164e-03  4.178978e-02
# 1925-01-22   1.320287e-13  1.937005e-04  1.692996e-13  1.290949e-03
# 1902-11-21   9.901551e-01  1.142382e+00  1.840662e-03  4.955181e-02
# 1925-02-17   2.918170e+00  1.314147e-01  3.690330e-01  2.357034e-08
#
#             NorESM2-MM  SAM0-UNICON   TaiESM1
# time
# 1953-10-26    2.713473     0.659440  0.129196
# 1921-10-22    7.909935     0.206765  2.018346
# 1925-01-22    0.183711     1.733777  0.932259
# 1902-11-21    0.000068    12.988330  0.005468
# 1925-02-17    0.036247     0.298767  2.923645
#
# [5 rows x 25 columns]

# %%
numeric_cols = list(X_train.select_dtypes(include='number'))

numeric_cols_hist = alt.Chart(X_train).mark_bar().encode(
    alt.X(alt.repeat(), bin=alt.Bin(maxbins=50)),
    alt.Y('count()', axis=alt.Axis(title='Count'), stack=False)
).properties(
    width=250,
    height=150
).repeat(repeat=numeric_cols, columns = 3).properties(
    title='Histogram chart of the Sydney Rain dataset per each numeric feature'
)

numeric_cols_hist
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# <img src="img/corr_plot_1.png" >
# <img src="img/corr_plot_2.png" >
# <img src="img/corr_plot_3.png" >

# %%
X_train.corr('spearman').style.background_gradient()
# Out:
# <style type="text/css">
# #T_c0165_row0_col0, #T_c0165_row1_col1, #T_c0165_row2_col2, #T_c0165_row3_col3, #T_c0165_row4_col4, #T_c0165_row5_col5, #T_c0165_row6_col6, #T_c0165_row7_col7, #T_c0165_row8_col8, #T_c0165_row9_col9, #T_c0165_row10_col10, #T_c0165_row11_col11, #T_c0165_row12_col12, #T_c0165_row13_col13, #T_c0165_row14_col14, #T_c0165_row15_col15, #T_c0165_row16_col16, #T_c0165_row17_col17, #T_c0165_row18_col18, #T_c0165_row19_col19, #T_c0165_row20_col20, #T_c0165_row21_col21, #T_c0165_row22_col22, #T_c0165_row23_col23, #T_c0165_row24_col24 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c0165_row0_col1, #T_c0165_row0_col2, #T_c0165_row0_col13, #T_c0165_row0_col20, #T_c0165_row0_col21, #T_c0165_row0_col22, #T_c0165_row1_col0, #T_c0165_row1_col2, #T_c0165_row1_col21, #T_c0165_row2_col0, #T_c0165_row2_col1, #T_c0165_row2_col12, #T_c0165_row2_col17, #T_c0165_row2_col22, #T_c0165_row3_col1, #T_c0165_row3_col2, #T_c0165_row3_col13, #T_c0165_row3_col14, #T_c0165_row4_col7, #T_c0165_row4_col10, #T_c0165_row4_col19, #T_c0165_row4_col23, #T_c0165_row5_col14, #T_c0165_row5_col15, #T_c0165_row5_col22, #T_c0165_row6_col0, #T_c0165_row6_col2, #T_c0165_row6_col3, #T_c0165_row6_col8, #T_c0165_row6_col19, #T_c0165_row7_col0, #T_c0165_row7_col2, #T_c0165_row7_col3, #T_c0165_row7_col15, #T_c0165_row8_col3, #T_c0165_row8_col19, #T_c0165_row8_col24, #T_c0165_row9_col12, #T_c0165_row9_col13, #T_c0165_row10_col0, #T_c0165_row10_col2, #T_c0165_row10_col3, #T_c0165_row10_col15, #T_c0165_row11_col3, #T_c0165_row11_col4, #T_c0165_row11_col16, #T_c0165_row11_col21, #T_c0165_row12_col2, #T_c0165_row12_col9, #T_c0165_row12_col10, #T_c0165_row12_col13, #T_c0165_row12_col14, #T_c0165_row12_col19, #T_c0165_row12_col21, #T_c0165_row12_col22, #T_c0165_row13_col0, #T_c0165_row13_col1, #T_c0165_row13_col2, #T_c0165_row13_col12, #T_c0165_row13_col15, #T_c0165_row14_col10, #T_c0165_row15_col3, #T_c0165_row15_col19, #T_c0165_row15_col20, #T_c0165_row16_col6, #T_c0165_row16_col22, #T_c0165_row17_col2, #T_c0165_row17_col3, #T_c0165_row17_col4, #T_c0165_row17_col21, #T_c0165_row18_col13, #T_c0165_row18_col21, #T_c0165_row18_col22, #T_c0165_row19_col1, #T_c0165_row19_col4, #T_c0165_row19_col8, #T_c0165_row19_col16, #T_c0165_row20_col13, #T_c0165_row20_col21, #T_c0165_row21_col0, #T_c0165_row21_col12, #T_c0165_row21_col17, #T_c0165_row21_col19, #T_c0165_row21_col23, #T_c0165_row22_col4, #T_c0165_row22_col9, #T_c0165_row22_col18, #T_c0165_row22_col19, #T_c0165_row22_col20, #T_c0165_row23_col15, #T_c0165_row23_col16, #T_c0165_row24_col2, #T_c0165_row24_col14 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c0165_row0_col3, #T_c0165_row0_col12, #T_c0165_row4_col12, #T_c0165_row6_col4, #T_c0165_row6_col15, #T_c0165_row6_col16, #T_c0165_row6_col18, #T_c0165_row7_col14, #T_c0165_row8_col12, #T_c0165_row8_col13, #T_c0165_row9_col21, #T_c0165_row10_col4, #T_c0165_row10_col8, #T_c0165_row10_col14, #T_c0165_row10_col16, #T_c0165_row10_col22, #T_c0165_row12_col0, #T_c0165_row12_col4, #T_c0165_row12_col18, #T_c0165_row13_col3, #T_c0165_row13_col4, #T_c0165_row13_col8, #T_c0165_row13_col14, #T_c0165_row13_col19, #T_c0165_row13_col20, #T_c0165_row15_col1, #T_c0165_row15_col5, #T_c0165_row15_col6, #T_c0165_row15_col7, #T_c0165_row15_col10, #T_c0165_row15_col11, #T_c0165_row15_col12, #T_c0165_row15_col13, #T_c0165_row15_col17, #T_c0165_row15_col23, #T_c0165_row15_col24, #T_c0165_row16_col7, #T_c0165_row19_col2, #T_c0165_row19_col13, #T_c0165_row21_col3, #T_c0165_row21_col9, #T_c0165_row21_col20, #T_c0165_row21_col22, #T_c0165_row24_col4, #T_c0165_row24_col15 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c0165_row0_col4, #T_c0165_row0_col7, #T_c0165_row1_col13, #T_c0165_row1_col19, #T_c0165_row2_col5, #T_c0165_row3_col18, #T_c0165_row3_col20, #T_c0165_row4_col0, #T_c0165_row4_col3, #T_c0165_row4_col17, #T_c0165_row5_col4, #T_c0165_row5_col8, #T_c0165_row5_col16, #T_c0165_row5_col21, #T_c0165_row6_col22, #T_c0165_row7_col18, #T_c0165_row7_col20, #T_c0165_row7_col21, #T_c0165_row7_col22, #T_c0165_row9_col10, #T_c0165_row10_col13, #T_c0165_row11_col0, #T_c0165_row13_col23, #T_c0165_row14_col19, #T_c0165_row14_col22, #T_c0165_row16_col5, #T_c0165_row16_col11, #T_c0165_row16_col12, #T_c0165_row16_col13, #T_c0165_row16_col24, #T_c0165_row17_col15, #T_c0165_row17_col22, #T_c0165_row18_col3, #T_c0165_row19_col14, #T_c0165_row20_col12, #T_c0165_row21_col8, #T_c0165_row21_col10, #T_c0165_row22_col0, #T_c0165_row22_col2, #T_c0165_row22_col10, #T_c0165_row22_col12, #T_c0165_row23_col13 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c0165_row0_col5, #T_c0165_row0_col14, #T_c0165_row0_col17, #T_c0165_row0_col23, #T_c0165_row1_col20, #T_c0165_row2_col9, #T_c0165_row2_col20, #T_c0165_row2_col24, #T_c0165_row3_col8, #T_c0165_row3_col10, #T_c0165_row6_col13, #T_c0165_row7_col1, #T_c0165_row7_col9, #T_c0165_row8_col6, #T_c0165_row8_col11, #T_c0165_row9_col2, #T_c0165_row11_col9, #T_c0165_row11_col12, #T_c0165_row12_col5, #T_c0165_row12_col23, #T_c0165_row13_col11, #T_c0165_row13_col17, #T_c0165_row14_col0, #T_c0165_row14_col24, #T_c0165_row17_col14, #T_c0165_row17_col16, #T_c0165_row18_col0, #T_c0165_row18_col1, #T_c0165_row18_col19, #T_c0165_row19_col3, #T_c0165_row19_col15, #T_c0165_row20_col0, #T_c0165_row21_col6, #T_c0165_row21_col13, #T_c0165_row21_col15, #T_c0165_row22_col1, #T_c0165_row22_col17, #T_c0165_row23_col14, #T_c0165_row24_col13 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c0165_row0_col6, #T_c0165_row1_col16, #T_c0165_row2_col4, #T_c0165_row2_col6, #T_c0165_row2_col11, #T_c0165_row3_col5, #T_c0165_row3_col19, #T_c0165_row4_col2, #T_c0165_row5_col19, #T_c0165_row6_col10, #T_c0165_row6_col20, #T_c0165_row7_col12, #T_c0165_row7_col13, #T_c0165_row8_col1, #T_c0165_row9_col7, #T_c0165_row10_col7, #T_c0165_row10_col17, #T_c0165_row11_col10, #T_c0165_row14_col23, #T_c0165_row15_col16, #T_c0165_row16_col9, #T_c0165_row16_col20, #T_c0165_row18_col5, #T_c0165_row20_col1, #T_c0165_row20_col7, #T_c0165_row22_col8, #T_c0165_row22_col23, #T_c0165_row22_col24, #T_c0165_row23_col9, #T_c0165_row24_col9 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c0165_row0_col8, #T_c0165_row0_col24, #T_c0165_row1_col7, #T_c0165_row1_col8, #T_c0165_row1_col9, #T_c0165_row1_col10, #T_c0165_row2_col14, #T_c0165_row2_col15, #T_c0165_row2_col18, #T_c0165_row3_col6, #T_c0165_row3_col15, #T_c0165_row4_col20, #T_c0165_row5_col20, #T_c0165_row7_col10, #T_c0165_row8_col2, #T_c0165_row9_col1, #T_c0165_row9_col5, #T_c0165_row9_col6, #T_c0165_row9_col11, #T_c0165_row9_col15, #T_c0165_row9_col16, #T_c0165_row9_col23, #T_c0165_row10_col11, #T_c0165_row10_col23, #T_c0165_row11_col1, #T_c0165_row11_col19, #T_c0165_row11_col20, #T_c0165_row12_col7, #T_c0165_row12_col11, #T_c0165_row12_col24, #T_c0165_row13_col6, #T_c0165_row13_col7, #T_c0165_row13_col24, #T_c0165_row14_col2, #T_c0165_row15_col4, #T_c0165_row16_col0, #T_c0165_row16_col2, #T_c0165_row17_col9, #T_c0165_row17_col10, #T_c0165_row17_col19, #T_c0165_row17_col20, #T_c0165_row18_col2, #T_c0165_row18_col11, #T_c0165_row18_col17, #T_c0165_row18_col23, #T_c0165_row19_col5, #T_c0165_row19_col17, #T_c0165_row19_col24, #T_c0165_row20_col2, #T_c0165_row20_col19, #T_c0165_row22_col11, #T_c0165_row23_col1, #T_c0165_row23_col10, #T_c0165_row23_col19, #T_c0165_row23_col20 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c0165_row0_col9, #T_c0165_row1_col12, #T_c0165_row1_col18, #T_c0165_row3_col4, #T_c0165_row3_col7, #T_c0165_row3_col9, #T_c0165_row3_col17, #T_c0165_row4_col5, #T_c0165_row4_col11, #T_c0165_row5_col18, #T_c0165_row8_col23, #T_c0165_row9_col0, #T_c0165_row9_col19, #T_c0165_row10_col19, #T_c0165_row11_col18, #T_c0165_row12_col1, #T_c0165_row12_col16, #T_c0165_row12_col17, #T_c0165_row13_col5, #T_c0165_row13_col10, #T_c0165_row14_col6, #T_c0165_row15_col0, #T_c0165_row16_col1, #T_c0165_row17_col0, #T_c0165_row17_col8, #T_c0165_row18_col6, #T_c0165_row18_col24, #T_c0165_row19_col7, #T_c0165_row19_col20, #T_c0165_row20_col10, #T_c0165_row21_col5, #

# %% [markdown]
# <img src="img/corr_plot_4.png" >

# %%
numeric_cols = list(X_train.select_dtypes(include='number'))
aly.corr(X_train[numeric_cols])
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
### Step 5: Model Training
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=123)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=123)

# %%
model_predictions = model.predict(X_train)

rmse_scores = {'Model':[],
               'RMSE Scores':[]}
for column in X_train.columns.to_list():
    rmse_scores['Model'].append(column)
    rmse_scores['RMSE Scores'].append(mean_squared_error(X_train[column],
                                                         y_train))
rmse_scores['Model'].append('RFR_Preds')
rmse_scores['RMSE Scores'].append(mean_squared_error(model_predictions,
                                                     y_train))

rmse_scores_df = pd.DataFrame(rmse_scores)
rmse_scores_df
# Out:
#                Model  RMSE Scores
# 0         ACCESS-CM2   111.666622
# 1      ACCESS-ESM1-5   113.284866
# 2     AWI-ESM-1-1-LR   118.308166
# 3        BCC-CSM2-MR   105.982389
# 4           BCC-ESM1   101.429067
# 5       CMCC-CM2-HR4   107.193705
# 6       CMCC-CM2-SR5   119.585524
# 7          CMCC-ESM2   114.773506
# 8            CanESM5   111.752399
# 9   EC-Earth3-Veg-LR    98.052564
# 10         FGOALS-g3    86.208758
# 11          GFDL-CM4    97.804941
# 12         INM-CM4-8   122.953733
# 13         INM-CM5-0   135.134065
# 14         KIOST-ESM    84.576195
# 15            MIROC6   126.238733
# 16   MPI-ESM-1-2-HAM   112.679127
# 17     MPI-ESM1-2-HR    90.058675
# 18     MPI-ESM1-2-LR    93.739163
# 19        MRI-ESM2-0    92.333783
# 20             NESM3    87.832444
# 21        NorESM2-LM    98.371004
# 22        NorESM2-MM   114.133758
# 23       SAM0-UNICON   128.113276
# 24           TaiESM1   121.188550
# 25         RFR_Preds     9.677582

# %% [markdown]
# #### Step 6: Discussion
# The table above presents the Root Mean Square Error (RMSE) scores for 25 different models and our Random Forest Regression Model. From the table, we can make this observation that the Random Forest Regression model, with a score of 9.67. This indicates that it has the best performance in terms of prediction accuracy among all listed models.
# The model with the highest RMSE score is INM-CM5-0, with a score of 135.134065. This suggests that this model has the poorest performance in terms of prediction accuracy of the rain in Sydney among all the models presented.
# The majority of the models have RMSE scores ranging from 84.576195 (KIOST-ESM) to 135.134065 (INM-CM5-0). This range represents the varying degrees of prediction accuracy for the models.

# %% [markdown]
# ## Part 2:

# %% [markdown]
# ### Preparation for deploying model next week

# %% [markdown]
# ***NOTE: Complete Question 4 (`Milestone3-task4.ipynb`) from the milestone 3 before coming here***

# %% [markdown]
# We’ve found the best hyperparameter settings with MLlib (from the Question 4 from milestone3), here we then use the same hyperparameters to train a scikit-learn model.

# %%
# Just replace ___ with the numbers you found from Milestone3-task4.ipynb
model = RandomForestRegressor(n_estimators=100, 
                              max_depth=5)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5)

# %%
print(f"Train RMSE: {mean_squared_error(y_train, model.predict(X_train), squared=False):.2f}")
print(f" Test RMSE: {mean_squared_error(y_test, model.predict(X_test), squared=False):.2f}")
# Out:
# Train RMSE: 7.90
#  Test RMSE: 8.64

# %%
# ready to deploy
# where this model is saved? Understand the concept of relative path.
dump(model, "model.joblib")
# Out:
# ['model.joblib']

# %%
# !aws s3 cp model.joblib s3://mds-s3-4-mrnabiz/output/model.joblib

# %% [markdown]
# ***Upload model.joblib to s3 under output folder. You choose how you want to upload it (using CLI, SDK, or web console).*** Web console is also completely fine as it is a small file.
